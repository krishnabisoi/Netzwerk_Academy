# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing 

from sklearn.model_selection import train_test_split

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
train_data = pd.read_csv("F://Krishna/Kirshna-Learnings/Netzwerk Academy/Practice/Telegram Desktop/train.csv")

test_data = pd.read_csv("F://Krishna/Kirshna-Learnings/Netzwerk Academy/Practice/Telegram Desktop/test.csv")

# %%
train_data.head(5)
# Out:
#    data1  data2 data3      data4   data5  data6     data7  data8 data9 data10  \
# 0      8    279     C  14.451155  1139.0    1.0  9.302908    1.0     M      p
# 1      1    108     H  14.207448  1656.0    1.0  7.220130    0.0     M      p
# 2      8    258     A  19.220830  2817.0    1.0  8.727214    1.0     M      p
# 3      4    147     A  15.752732  1948.0    1.0  6.078818    1.0     M      p
# 4      5    230     H  10.195407  1336.0    1.0  4.749185    0.0     M      p
#
#       output
# 0  86.108947
# 1  42.606833
# 2  85.625961
# 3  53.656277
# 4  64.925051

# %%
train_data.tail(5)
# Out:
#       data1  data2 data3      data4   data5  data6     data7  data8 data9  \
# 9995      9    263     A  16.604215  1070.0    0.0  8.979149    2.0     F
# 9996      5    280     E  28.758911  2652.0    0.0  3.574129    0.0     F
# 9997      6    188     D  15.963267  1359.0    0.0  2.880019    0.0     F
# 9998      1    132     H  11.683401  1793.0    0.0  6.983192    2.0     F
# 9999      5    264     A  21.176115  1792.0    0.0  8.276101    2.0     F
#
#      data10     output
# 9995      p  85.922943
# 9996      p  90.857149
# 9997      p  61.246960
# 9998      p  45.298253
# 9999      p  85.534604

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# data1     10000 non-null int64
# data2     10000 non-null int64
# data3     10000 non-null object
# data4     10000 non-null float64
# data5     10000 non-null int64
# data6     10000 non-null int64
# data7     10000 non-null float64
# data8     10000 non-null int64
# data9     10000 non-null object
# data10    10000 non-null object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.3+ KB

# %%
print("unique values of data1 col: ", train_data["data1"].unique())
print("\nunique values of data2 col: ", train_data["data2"].unique())
print("\nunique values of data3 col: ", train_data["data3"].unique())
print("\nunique values of data4 col: ", train_data["data4"].unique())
print("\nunique values of data5 col: ", train_data["data5"].unique())
print("\nunique values of data6 col: ", train_data["data6"].unique())
print("\nunique values of data7 col: ", train_data["data7"].unique())
print("\nunique values of data8 col: ", train_data["data8"].unique())
print("\nunique values of data9 col: ", train_data["data9"].unique())
print("\nunique values of data10 col: ", train_data["data10"].unique())
# Out:
# unique values of data1 col:  [  8   1   4   5   3   2   0   7   9 200   6]
#
# unique values of data2 col:  [279 108 258 147 230 233 225 240 208 296 257 216 107 197 280 192 220 157
#  223 169 104 268 155 231 242 248 263 175 184 238 121 133 284 159 128 250
#  288 219 282 172 221 150 102 178 195 218 100 152 132 265 210 165 281 289
#  196 269 149 139 148 177 229 254 113 123 189 232 213 129 191 119 246 251
#  234 198 173 170 227 200 275 199 212 287 235 101 222 190 203 142 292 179
#  276 193 125 115 241 294 293 262 290 245 109 228 145 204 299 160 283 124
#  207 205 112 249 253 270 259 162 261 180 141 224 201 277 103 206 267 127
#  116 176 291 161 126 120 226 272 252 136 167 214 134 266 185 131 171 137
#  135 237 117 106 239 183 158 274 271 168 110 194 286 166 114 143 186 151
#  298 264 244 243 260 164 181 209 273 122 256 285 255 278 146 217 144 174
#  187 211 182 154 202 153 156 247 130 297 163 236 138 215 188 140 111 295
#  118 105]
#
# ...

# %%
train_data.dropna(axis = 0, inplace = True)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# data1     10000 non-null int64
# data2     10000 non-null int64
# data3     10000 non-null object
# data4     10000 non-null float64
# data5     10000 non-null int64
# data6     10000 non-null int64
# data7     10000 non-null float64
# data8     10000 non-null int64
# data9     10000 non-null object
# data10    10000 non-null object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.3+ KB

# %%
label_encoder = preprocessing.LabelEncoder() 

#For Training
train_data['data3']= label_encoder.fit_transform(train_data['data3']) 
train_data['data9']= label_encoder.fit_transform(train_data['data9'])
train_data['data10']= label_encoder.fit_transform(train_data['data10']) 
   
#For Testing
test_data['data3']= label_encoder.fit_transform(test_data['data3']) 
test_data['data9']= label_encoder.fit_transform(test_data['data9'])
test_data['data10']= label_encoder.fit_transform(test_data['data10'])

# %%
train_data.head(5)
# Out:
#    data1  data2  data3      data4   data5  data6     data7  data8  data9  \
# 0      8    279      2  14.451155  1139.0    1.0  9.302908    1.0      1
# 1      1    108      7  14.207448  1656.0    1.0  7.220130    0.0      1
# 2      8    258      0  19.220830  2817.0    1.0  8.727214    1.0      1
# 3      4    147      0  15.752732  1948.0    1.0  6.078818    1.0      1
# 4      5    230      7  10.195407  1336.0    1.0  4.749185    0.0      1
#
#    data10     output
# 0       0  86.108947
# 1       0  42.606833
# 2       0  85.625961
# 3       0  53.656277
# 4       0  64.925051

# %%
train_data.tail(5)
# Out:
#       data1  data2  data3      data4   data5  data6     data7  data8  data9  \
# 9995      9    263      0  16.604215  1070.0    0.0  8.979149    2.0      0
# 9996      5    280      4  28.758911  2652.0    0.0  3.574129    0.0      0
# 9997      6    188      3  15.963267  1359.0    0.0  2.880019    0.0      0
# 9998      1    132      7  11.683401  1793.0    0.0  6.983192    2.0      0
# 9999      5    264      0  21.176115  1792.0    0.0  8.276101    2.0      0
#
#       data10     output
# 9995       0  85.922943
# 9996       0  90.857149
# 9997       0  61.246960
# 9998       0  45.298253
# 9999       0  85.534604

# %%
train_data.isnull().sum()
# Out:
# data1     0
# data2     0
# data3     0
# data4     0
# data5     0
# data6     0
# data7     0
# data8     0
# data9     0
# data10    0
# output    0
# dtype: int64

# %%
np.any(np.isnan(train_data)) #Checking for null values, If True is op then there are null or else Flase
# Out:
# False

# %%
#plotting the data1 attribute in scatterplot and finding OULIERS.
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data1'], y = train_data['output'])

# %%
#Finding Outlier, removing it using For loop.
i = train_data.loc[train_data['data1'] > 75].index
print(i)
train_data.drop(i, inplace = True)
# Out:
# Int64Index([18], dtype='int64')

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data1'], y = train_data['output'])

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
_ = train_data['data1'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = train_data['data3'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = train_data['data8'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = train_data['data9'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = train_data['data10'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = train_data['data1'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data2'], y = train_data['output'])

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data4'], y = train_data['output'])

# %%
#Finding Outlier, removing it using For loop.
i = train_data.loc[train_data['data4'] > 50].index
print(i)
train_data.drop(i, inplace = True)

i = train_data.loc[train_data['data4'] < 10].index
print(i)
train_data.drop(i, inplace = True)
# Out:
# Int64Index([33], dtype='int64')
# Int64Index([81], dtype='int64')

# %%
#data4 after removing 2 OUTLIERS
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data4'], y = train_data['output'])

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data5'], y = train_data['output'])

# %%
#data4 after removing 2 OUTLIERS
i = train_data.loc[train_data['data5'] < 500].index
print(i)
train_data.drop(i, inplace = True)
# Out:
# Int64Index([46], dtype='int64')

# %%
#data5 after removing 1 OUTLIERS
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data5'], y = train_data['output'])

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data6'], y = train_data['output'])

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = train_data['data7'], y = train_data['output'])

# %%
#deleting data10 attribute because the field is not meaningful

del train_data["data10"]
del test_data["data10"]

# %%
train_data
# Out:
#       data1  data2  data3      data4   data5  data6     data7  data8  data9  \
# 0         8    279      2  14.451155  1139.0    1.0  9.302908    1.0      1
# 1         1    108      7  14.207448  1656.0    1.0  7.220130    0.0      1
# 2         8    258      0  19.220830  2817.0    1.0  8.727214    1.0      1
# 3         4    147      0  15.752732  1948.0    1.0  6.078818    1.0      1
# 4         5    230      7  10.195407  1336.0    1.0  4.749185    0.0      1
# 5         3    233      5  21.052830  2571.0    1.0  9.603920    2.0      1
# 6         2    225      1  27.926836  2630.0    1.0  6.173447    2.0      1
# 7         4    225      5  11.263795  1643.0    1.0  2.537428    1.0      1
# 8         0    240      0  10.621867  2945.0    1.0  2.015180    1.0      1
# 9         8    208      6  17.706433  1804.0    1.0  9.252709    1.0      1
# 10        7    296      5  21.955849  2253.0    1.0  3.315468    0.0      1
# ...

# %%
X = train_data.drop(['output'], axis = 1, inplace = False)
y = train_data['output']

# %%
#splitting the train data and test data
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state = 10)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7494, 9) (2499, 9) (7494,) (2499,)

# %%
#trainig the model with train data
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#predicting the output of test data and comparing with actual output
y_pred = regressor.predict(X_test)


df_predict = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_predict
# Out:
#          Actual  Predicted
# 1643  78.109018  78.109018
# 1348  47.901732  47.901732
# 3425  76.584313  76.584313
# 1352  70.346561  70.346561
# 8078  81.167425  81.167425
# 944   51.938924  51.938924
# 1379  64.001484  64.001484
# 4521  85.423094  85.423094
# 6090  70.311899  70.311899
# 7042  55.941119  55.941119
# 5369  92.143684  92.143684
# 7223  64.240700  64.240700
# 2723  34.116805  34.116805
# 5664  58.961868  58.961868
# 1411  56.737059  56.737059
# 2538  68.401420  68.401420
# 7293  59.993217  59.993217
# 8180  69.105020  69.105020
# 452   89.013017  89.013017
# 574   65.065799  65.065799
# 4694  63.976118  63.976118
# 7398  67.057981  67.057981
# 3894  73.438663  73.438663
# 3361  82.819038  82.819038
# 2236  81.949323  81.949323
# 8037  72.405996  72.405996
# 405   57.392465  57.392465
# 58    64.574552  64.574552
# 3373  84.200804  84.200804
# 1366  55.556852  55.556852
# ...         ...        ...
# 8961  57.240969  57.240969
# 5723  76.687536  76.687536
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-58dd2cee7c6e> in <module>
#       1 knn = KNeighborsClassifier(n_neighbors=9)
# ----> 2 knn.fit(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     904             self.outputs_2d_ = True
#     905
# --> 906         check_classification_targets(y)
#     907         self.classes_ = []
#     908         self._y = np.empty(y.shape, dtype=np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# --> 169         raise ValueError("Unknown label type: %r" % y_type)
#     170
#     171
#
# ValueError: Unknown label type: 'continuous'

# %%
#as the above KNN classification cannot be used in continuous data

#therefore using KNN regression for continuous data 
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=9)
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                     weights='uniform')

# %%
y_pred = knn.predict(X_test)
df_predict = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_predict
# Out:
#          Actual  Predicted
# 1643  78.109018  76.264837
# 1348  47.901732  45.902519
# 3425  76.584313  79.293530
# 1352  70.346561  68.610158
# 8078  81.167425  81.364960
# 944   51.938924  56.291078
# 1379  64.001484  61.512806
# 4521  85.423094  79.283747
# 6090  70.311899  73.388983
# 7042  55.941119  60.704907
# 5369  92.143684  86.350085
# 7223  64.240700  74.876795
# 2723  34.116805  44.692743
# 5664  58.961868  55.002592
# 1411  56.737059  51.620696
# 2538  68.401420  73.800837
# 7293  59.993217  60.315168
# 8180  69.105020  69.870498
# 452   89.013017  85.887707
# 574   65.065799  65.954173
# 4694  63.976118  65.874668
# 7398  67.057981  64.677060
# 3894  73.438663  62.419136
# 3361  82.819038  77.464215
# 2236  81.949323  78.353143
# 8037  72.405996  74.250055
# 405   57.392465  50.650989
# 58    64.574552  55.586233
# 3373  84.200804  87.659339
# 1366  55.556852  60.441312
# ...         ...        ...
# 8961  57.240969  61.279982
# 5723  76.687536  72.416813
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8424354504022746
